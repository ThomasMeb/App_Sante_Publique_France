# %%
import pandas as pd
from pulp import *

# %%
data = pd.read_csv("data_clean.csv")
# Out:
# /tmp/ipykernel_521480/4104122689.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data_clean.csv")

# %%
data
# Out:
#                                                   produit           code  \
# 0       Bonneterre : Chocolat Noir Costa Rica 75% De C...  3396410047559
# 1                          Franprix : Dégustation Lait...  3263850583117
# 2       Gullon : Biscuits Petit-Déjeuner Céréales Comp...  8410376046991
# 3                           Aurada : Galletas Tostadas...       24044011
# 4                         SuperSol : Galletas Tostadas...  8430803027171
# ...                                                   ...            ...
# 196294                          Tartex : Pâté Shiitake...  4005514171303
# 196295       Gourmet Garden : Coriandre Gourmet Garden...     7520800065
# 196296                   Nacional : Spaghetti classica...  5601066644471
# 196297  Maggi : Soupe de queue de boeuf (potage oxtail...  5601001001604
# 196298                    Milaneza : Linguine al pesto...  5601286260024
#
#                 pnns_groups_1  energy_100g  fat_100g  saturated-fat_100g  \
# 0               Sugary snacks        556.0      44.0           27.000000
# 1               Sugary snacks        572.4      38.0           22.000000
# 2               Sugary snacks        413.2      14.0            1.300000
# 3               Sugary snacks        425.6      10.0            5.000000
# 4               Sugary snacks        425.6      10.0            5.000000
# ...                       ...          ...       ...                 ...
# 196294  Fruits and vegetables        214.7      17.9            4.749687
# 196295          Sugary snacks         10.0       0.3            4.749687
# 196296   Cereals and potatoes        348.2       1.8            0.400000
# 196297        Composite foods        366.3      11.9            0.500000
# 196298   Cereals and potatoes        345.1       1.9            0.400000
#
#         carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  sodium_100g
# 0                30.000000    24.000000      10.000000   0.030000     0.011811
# 1                50.000000    49.000000       7.600000   0.190000     0.074803
# 2                65.000000     1.400000       6.800000   0.650000     0.255906
# 3                77.000000    21.000000       6.900000   0.780000     0.307087
# 4                77.000000    21.000000       6.900000   0.780000     0.307087
# ...                    ...          ...            ...        ...          ...
# 196294            6.400000    16.592037       7.000000   1.267303     0.498955
# 196295           33.922107    16.592037       7.099545   0.127000     0.050000
# 196296           71.000000     5.000000      12.000000   0.010160     0.004000
# 196297           51.800000     7.200000      13.000000  14.732000     5.800000
# 196298           70.000000     3.300000      12.000000   0.254000     0.100000
#
# [196299 rows x 11 columns]

# %%
# Demande à l'utilisateur de saisir son âge, son genre et son niveau d'activité physique
age = int(input("Entrez votre âge: "))
gender = input("Entrez votre genre (M ou F): ")
activity_level = input("Entrez votre niveau d'activité physique (0-5): ")

# Calcule les besoins en nutriments de l'utilisateur en utilisant des guides de consommation de nourriture recommandés
if gender == "M":
  if age < 18:
    # Besoins en nutriments pour les hommes de moins de 18 ans
    nutrient_needs = {
      "calories": 2500,
      "protein": 75,
      "fat": 60,
      "carbohydrates": 300
    }
  elif age < 30:
    # Besoins en nutriments pour les hommes de 18 à 29 ans
    nutrient_needs = {
      "calories": 2800,
      "protein": 90,
      "fat": 65,
      "carbohydrates": 350
    }
  elif age < 50:
    # Besoins en nutriments pour les hommes de 30 à 49 ans
    nutrient_needs = {
      "calories": 2600,
      "protein": 80,
      "fat": 60,
      "carbohydrates": 325
    }
  else:
    # Besoins en nutriments pour les hommes de 50 ans et plus
    nutrient_needs = {
      "calories": 2400,
      "protein": 75,
      "fat": 55,
      "carbohydrates": 300
    }
else:
  if age < 18:
    # Besoins en nutriments pour les femmes de moins de 18 ans
    nutrient_needs = {
      "calories": 2000,
      "protein": 65,
      "fat": 45,
      "carbohydrates": 250
    }
  elif age < 30:
    # Besoins en nutriments pour les femmes de 18 à 29 ans
    nutrient_needs = {
      "calories": 2200,
      "protein": 70,
      "fat": 50,
      "carbohydrates": 275
    }
  elif age < 50:
    # Besoins en nutriments pour les femmes de 30 à 49 ans
    nutrient_needs = {
      "calories": 2100,
      "protein": 65,
      "fat": 45,
      "carbohydrates": 250
    }
  else:
    # Besoins en nutriments pour les femmes de 50 ans et plus
    nutrient_needs = {
      "calories": 1900,
      "protein": 60,
      "fat": 40,
      "carbohydrates": 225
    }

# Ajuste les besoins en nutriments en fonction du niveau d'activité physique de l'utilisateur
if activity_level == "0":
  # Pas d'ajustement nécessaire pour un niveau d'activité physique très faible
  pass
elif activity_level == "1":
  # Ajuste les besoins en nutriments pour un niveau d'activité physique faible
  nutrient_needs["calories"] += 200
  nutrient_needs["carbohydrates"] += 50
elif activity_level == "2":
  # Ajuste les besoins en nutriments pour un niveau d'activité physique modéré
  nutrient_needs["calories"] += 400
  nutrient_needs["carbohydrates"] += 100
elif activity_level == "3":
  # Ajuste les besoins en nutriments pour un niveau d'activité physique élevé
  nutrient_needs["calories"] += 600
  nutrient_needs["carbohydrates"] += 150
elif activity_level == "4":
  # Ajuste les besoins en nutriments pour un niveau d'activité physique très élevé
  nutrient_needs["calories"] += 800
  nutrient_needs["carbohydrates"] += 200
elif activity_level == "5":
  # Ajuste les besoins en nutriments pour un niveau d'activité physique extrêmement élevé
  nutrient_needs["calories"] += 1000
  nutrient_needs["carbohydrates"] += 250

# Affiche les besoins en nutriments de l'utilisateur
print("Voici vos besoins en nutriments:")
for nutrient, value in nutrient_needs.items():
  print(f"{nutrient}: {value}")
# Out:
# Entrez votre âge: 23
# Entrez votre genre (M ou F): M
# Entrez votre niveau d'activité physique (0-5): 4
# Voici vos besoins en nutriments:
# calories: 3600
# protein: 90
# fat: 65
# carbohydrates: 550

# %%
# Fonction qui trouve les 5 combinaisons d'aliments les plus optimisées sous forme de menu journalier
def find_optimal_food_combinations(nutrient_needs, data):
  # Définition des poids pour chaque groupe PNNS
    pnns_weights = {
      "Sugary snacks": 0.5,
      "Cereals and potatoes": 0.5,
      "Milk and dairy products": 0.8,
      "Composite foods": 0.7,
      "Beverages": 0.5,
      "Fat and sauces": 0.6,
      "Fish Meat Eggs": 0.9,
      "Fruits and vegetables": 0.9,
      "Salty snacks": 0.5
  }
    
    # Création du problème de programmation linéaire
    prob = LpProblem("Menu Optimization", LpMinimize)

    # Définition des variables de décision
    food_vars = LpVariable.dicts("Food", (row["code"] for index, row in data.iterrows()), lowBound=0, cat='Continuous')

    prob += lpSum([food_vars[row["code"]] * (row["energy_100g"] - nutrient_needs["calories"]) for index, row in data.iterrows()]) + \
               lpSum([food_vars[row["code"]] * (row["proteins_100g"] - nutrient_needs["protein"]) for index, row in data.iterrows()]) + \
               lpSum([food_vars[row["code"]] * (row["fat_100g"] - nutrient_needs["fat"]) for index, row in data.iterrows()]) + \
               lpSum([food_vars[row["code"]] * (row["carbohydrates_100g"] - nutrient_needs["carbohydrates"]) for index, row in data.iterrows()]) + \
             lpSum([food_vars[row["code"]] * pnns_weights.get(row["pnns_groups_1"], 0) for index, row in data.iterrows()])

    # Résolution du problème
    solver = GLPK()
    solver.solve(prob)
    
    # Définition des variables de décision
    food_vars = LpVariable.dicts("Food", (index for index, row in data.iterrows()), lowBound=0, cat='Continuous')

    # Affichage des résultats
    print("Voici les 5 combinaisons d'aliments les plus optimisées sous forme de menu journalier :")
    for index, row in data.iterrows():
        if food_vars[f"{index}"].varValue > 0:
            print(f"{row['produit']} ({food_vars[f'{index}'].varValue} portion(s))")

# %%
# Fonction qui trouve les 5 combinaisons d'aliments les plus optimisées sous forme de menu journalier
def find_optimal_food_combinations(nutrient_needs, data):
  # Définition des poids pour chaque groupe PNNS
    pnns_weights = {
      "Sugary snacks": 0.5,
      "Cereals and potatoes": 0.5,
      "Milk and dairy products": 0.8,
      "Composite foods": 0.7,
      "Beverages": 0.5,
      "Fat and sauces": 0.6,
      "Fish Meat Eggs": 0.9,
      "Fruits and vegetables": 0.9,
      "Salty snacks": 0.5
  }
    # Création du problème de programmation linéaire
    prob = LpProblem("Menu Optimization", LpMinimize)

    # Définition des variables de décision
    food_vars = LpVariable.dicts("Food", (row["code"] for index, row in data.iterrows()), lowBound=0, cat='Continuous')
    
    
    duplicate_keys = []

    # Détection des doublons
    for key, value in food_vars.items():
        if food_vars.get(key) != value:
            duplicate_keys.append(key)

    # Suppression des doublons
    for key in duplicate_keys:
        food_vars.pop(key, None)
    
    
    prob += lpSum([food_vars[row["code"]] * (row["energy_100g"] - nutrient_needs["calories"]) for index, row in data.iterrows()]) + \
               lpSum([food_vars[row["code"]] * (row["proteins_100g"] - nutrient_needs["protein"]) for index, row in data.iterrows()]) + \
               lpSum([food_vars[row["code"]] * (row["fat_100g"] - nutrient_needs["fat"]) for index, row in data.iterrows()]) + \
               lpSum([food_vars[row["code"]] * (row["carbohydrates_100g"] - nutrient_needs["carbohydrates"]) for index, row in data.iterrows()]) + \
             lpSum([food_vars[row["code"]] * pnns_weights.get(row["pnns_groups_1"], 0) for index, row in data.iterrows()])

    # Résolution du problème
    solver = GLPK(msg=0)
    solver.solve(prob)

    # Définition des variables de décision
    food_vars = LpVariable.dicts("Food", (index for index, row in data.iterrows()), lowBound=0, cat='Continuous')

    # Affichage des résultats
    print("Voici les 5 combinaisons d'aliments les plus optimisées sous forme de menu journalier :")
    for index, row in data.iterrows():
        if food_vars[f"{index}"].varValue > 0:
            print(f"{row['produit']} ({food_vars[f'{index}'].varValue} portion(s))")

# %%
find_optimal_food_combinations(nutrient_needs, data)
# Out:
# ---------------------------------------------------------------------------
# PulpError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 find_optimal_food_combinations(nutrient_needs, data)
#
# Cell In[55], line 42, in find_optimal_food_combinations(nutrient_needs, data)
#      40 # Résolution du problème
#      41 solver = GLPK(msg=0)
# ---> 42 solver.solve(prob)
#      44 # Définition des variables de décision
#      45 food_vars = LpVariable.dicts("Food", (index for index, row in data.iterrows()), lowBound=0, cat='Continuous')
#
# File ~/.local/lib/python3.10/site-packages/pulp/apis/core.py:259, in LpSolver.solve(self, lp)
#     257 """Solve the problem lp"""
#     258 # Always go through the solve method of LpProblem
# --> 259 return lp.solve(self)
#
# File ~/.local/lib/python3.10/site-packages/pulp/pulp.py:1913, in LpProblem.solve(self, solver, **kwargs)
#    1911 # time it
#    1912 self.startClock()
# -> 1913 status = solver.actualSolve(self, **kwargs)
#    1914 self.stopClock()
#    1915 self.restoreObjective(wasNone, dummyVar)
#
# File ~/.local/lib/python3.10/site-packages/pulp/apis/glpk_api.py:77, in GLPK_CMD.actualSolve(self, lp)
#      75     raise PulpSolverError("PuLP: cannot execute " + self.path)
#      76 tmpLp, tmpSol = self.create_tmp_files(lp.name, "lp", "sol")
# ---> 77 lp.writeLP(tmpLp, writeSOS=0)
#      78 proc = ["glpsol", "--cpxlp", tmpLp, "-o", tmpSol]
#      79 if self.timeLimit:
#
# File ~/.local/lib/python3.10/site-packages/pulp/pulp.py:1796, in LpProblem.writeLP(self, filename, writeSOS, mip, max_length)
#    1784 def writeLP(self, filename, writeSOS=1, mip=1, max_length=100):
#    1785     """
#    1786     Write the given Lp problem to a .lp file.
#    1787
#    (...)
#    1794         - The file is created
#    1795     """
# -> 1796     return mpslp.writeLP(
#    1797         self, filename=filename, writeSOS=writeSOS, mip=mip, max_length=max_length
#    1798     )
#
# File ~/.local/lib/python3.10/site-packages/pulp/mps_lp.py:351, in writeLP(LpProblem, filename, writeSOS, mip, max_length)
#     349 vs = LpProblem.variables()
#     350 # check for repeated names
# --> 351 LpProblem.checkDuplicateVars()
#     352 # Bounds on non-"positive" variables
#     353 # Note: XPRESS and CPLEX do not interpret integer variables without
#     354 # explicit bounds
#     355 if mip:
#
# File ~/.local/lib/python3.10/site-packages/pulp/pulp.py:1815, in LpProblem.checkDuplicateVars(self)
#    1811 repeated_names = [
#    1812     (key, value) for key, value in list(repeated_names.items()) if value >= 2
#    1813 ]
#    1814 if repeated_names:
# -> 1815     raise const.PulpError("Repeated variable names:\n" + str(repeated_names))
#    1816 return 1
#
# PulpError: Repeated variable names:
# [('Food_72101011766', 2), ('Food_72101012305', 2), ('Food_75925301662', 2), ('Food_75925306056', 2), ('Food_75925306339', 2), ('Food_94723500053', 2)]

# %%
# Appel de la fonction "find_optimal_food_combinations"
find_optimal_food_combinations(nutrient_needs, data)
# Out:
# ---------------------------------------------------------------------------
# PulpError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 # Appel de la fonction "find_optimal_food_combinations"
# ----> 2 find_optimal_food_combinations(nutrient_needs, data)
#
# Cell In[53], line 30, in find_optimal_food_combinations(nutrient_needs, data)
#      28 # Résolution du problème
#      29 solver = GLPK()
# ---> 30 solver.solve(prob)
#      32 # Définition des variables de décision
#      33 food_vars = LpVariable.dicts("Food", (index for index, row in data.iterrows()), lowBound=0, cat='Continuous')
#
# File ~/.local/lib/python3.10/site-packages/pulp/apis/core.py:259, in LpSolver.solve(self, lp)
#     257 """Solve the problem lp"""
#     258 # Always go through the solve method of LpProblem
# --> 259 return lp.solve(self)
#
# File ~/.local/lib/python3.10/site-packages/pulp/pulp.py:1913, in LpProblem.solve(self, solver, **kwargs)
#    1911 # time it
#    1912 self.startClock()
# -> 1913 status = solver.actualSolve(self, **kwargs)
#    1914 self.stopClock()
#    1915 self.restoreObjective(wasNone, dummyVar)
#
# File ~/.local/lib/python3.10/site-packages/pulp/apis/glpk_api.py:77, in GLPK_CMD.actualSolve(self, lp)
#      75     raise PulpSolverError("PuLP: cannot execute " + self.path)
#      76 tmpLp, tmpSol = self.create_tmp_files(lp.name, "lp", "sol")
# ---> 77 lp.writeLP(tmpLp, writeSOS=0)
#      78 proc = ["glpsol", "--cpxlp", tmpLp, "-o", tmpSol]
#      79 if self.timeLimit:
#
# File ~/.local/lib/python3.10/site-packages/pulp/pulp.py:1796, in LpProblem.writeLP(self, filename, writeSOS, mip, max_length)
#    1784 def writeLP(self, filename, writeSOS=1, mip=1, max_length=100):
#    1785     """
#    1786     Write the given Lp problem to a .lp file.
#    1787
#    (...)
#    1794         - The file is created
#    1795     """
# -> 1796     return mpslp.writeLP(
#    1797         self, filename=filename, writeSOS=writeSOS, mip=mip, max_length=max_length
#    1798     )
#
# File ~/.local/lib/python3.10/site-packages/pulp/mps_lp.py:351, in writeLP(LpProblem, filename, writeSOS, mip, max_length)
#     349 vs = LpProblem.variables()
#     350 # check for repeated names
# --> 351 LpProblem.checkDuplicateVars()
#     352 # Bounds on non-"positive" variables
#     353 # Note: XPRESS and CPLEX do not interpret integer variables without
#     354 # explicit bounds
#     355 if mip:
#
# File ~/.local/lib/python3.10/site-packages/pulp/pulp.py:1815, in LpProblem.checkDuplicateVars(self)
#    1811 repeated_names = [
#    1812     (key, value) for key, value in list(repeated_names.items()) if value >= 2
#    1813 ]
#    1814 if repeated_names:
# -> 1815     raise const.PulpError("Repeated variable names:\n" + str(repeated_names))
#    1816 return 1
#
# PulpError: Repeated variable names:
# [('Food_72101011766', 2), ('Food_72101012305', 2), ('Food_75925301662', 2), ('Food_75925306056', 2), ('Food_75925306339', 2), ('Food_94723500053', 2)]
